# %% [markdown]
# ## Trabajo Práctico 3 - Equipo 2 -

# %% [markdown]
# ![i1.png](attachment:i1.png)

# %% [markdown]
# ![I2.png](attachment:I2.png)

# %% [markdown]
# ## Tabla de contenido

# %% [markdown]
# [1 - Extraccion de datos, limpieza y armado del set a procesar](./Armado_Datasets.ipynb)

# %% [markdown]
# ![I3.png](attachment:I3.png)

# %% [markdown]
# [2 - Exploración y entendimiento de las relaciones entre las columnas ](./EDA.ipynb)

# %% [markdown]
# - Con nuestro target no hay muchas variables correlacionadas, con la excepcion del stated_amount.
# - Stated_amount se relaciona con antiguedad, cantidad de siniestro previos.
# - Cantidad de siniestros tiene una fuerte relacion con aseguradoras previas y el tipo de participacion del asegurado.
# - Analizamos Stated_amount en relacion al resto de las variables.

# %% [markdown]
# ![i5.png](attachment:i5.png)

# %% [markdown]
# ![i6.png](attachment:i6.png)

# %% [markdown]
# [3 - Procesado de modelos  ](./Modelos.ipynb)

# %% [markdown]
# [4 - Análisis de resultados](./Analisis_resultados.ipynb)

# %% [markdown]
# ![I4.png](attachment:I4.png)

# %% [markdown]
# [5 - Adicional: descarte del uso de reducción de dimensiones (PCA)](./Análisis_PCA.ipynb)

# %% [markdown]
# ![i7.png](attachment:i7.png)

# %% [markdown]
# [6 - Adicional: Notebook de proceso usando CatBoost](./Bonus_CatBoost.ipynb)
